# %%
from copy import deepcopy
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('PILOT_TEAM_DATA20190711.csv').fillna(0)
df
# Out:
#       GLUSR_USR_ID                 GLUSR_USR_COMPANYNAME  FK_GL_CITY_ID  \
# 0           2231.0                       Sadani Overseas        70732.0
# 1           6233.0                   V & V Machine Tools        70480.0
# 2          17458.0            Trinetra Tours (P) Limited        70469.0
# 3          21771.0                 G. S. Auto Industries        73870.0
# 4          49204.0                          Lux Flavours        70706.0
# 5          59394.0                         Mahajan Udyog        70426.0
# 6          73522.0                       Ujwal Texprints        70632.0
# 7         102382.0             Gujarat Engineering Works        70491.0
# 8         109946.0                     Arm International        70754.0
# 9         136961.0                 Rajendera Enterprises        70422.0
# 10        154299.0                      Speed Lubricants        70632.0
# 11        170802.0            Garson Metal Rolling Mills        73794.0
# ...

# %%
df['Blconsumption'] = df['L30D_BL_CONSUME']/df['L30D_BL_ALOTTED'] 
df['PNSconsumption'] = df['L30D_PNS_ANS']/df['L30D_PNS'] 
df['Coverage'] = df['L30D_TTL_DURATION'] > 30
df.Coverage = df['Coverage'].astype(int)
df['BlconsumptionT'] = df['Blconsumption']  > .40
df['BlconsumptionT'] = df['BlconsumptionT'].astype(int)
df['PNSconsumptionT'] = df['PNSconsumption']  > .75
df['PNSconsumptionT'] = df['PNSconsumptionT'].astype(int)
df['PNSconsumptionT']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
# 5       0
# 6       1
# 7       0
# 8       0
# 9       0
# 10      0
# 11      0
# 12      0
# 13      1
# 14      1
# 15      1
# 16      0
# 17      0
# 18      0
# 19      1
# 20      1
# 21      0
# 22      0
# 23      1
# 24      1
# 25      1
# 26      1
# 27      0
# 28      0
# 29      1
#        ..
# 3197    1
# 3198    1
# 3199    0
# 3200    0
# 3201    1
# 3202    0
# 3203    1
# 3204    1
# 3205    1
# 3206    1
# 3207    0
# 3208    0
# 3209    0
# 3210    0
# 3211    1
# 3212    0
# 3213    1
# 3214    0
# 3215    1
# 3216    0
# 3217    0
# 3218    0
# 3219    0
# 3220    0
# 3221    0
# 3222    0
# 3223    0
# 3224    0
# 3225    1
# 3226    0
# Name: PNSconsumptionT, Length: 3227, dtype: int64

# %%
dfl3 = df.groupby(['L3_FSF_ID']).sum()
dfl3.to_csv('l3data.csv')
dfl3
# Out:
#            GLUSR_USR_ID  FK_GL_CITY_ID  FK_GL_STATE_ID  CUST_TO_SERV_ID  \
# L3_FSF_ID
# 2635.0     1.995567e+09      7141571.0        629336.0     1.169785e+08
# 3251.0     3.718521e+09     17562694.0       1569890.0     2.752166e+08
# 7485.0     2.822355e+10     86419849.0       7703278.0     1.555841e+09
# 16369.0    1.304713e+10     33604855.0       2990514.0     6.201318e+08
# 43484.0    2.518152e+09     14296282.0       1291973.0     2.178377e+08
# 50388.0    2.296156e+09      7418941.0        668326.0     1.353675e+08
# 73069.0    8.981455e+09     27528554.0       2459377.0     4.777967e+08
# 73331.0    1.061813e+09      4159115.0        369745.0     7.398488e+07
# 74689.0    1.650738e+08       385865.0         32448.0     6.097381e+06
# 74690.0    1.971513e+08      1081284.0         97371.0     1.785728e+07
# 75307.0    1.315879e+10     36043127.0       3188719.0     6.668274e+08
#
#                  STS_ID  ASSIGNEDTO  TELEASSIGNEDTO  PRD_CNT  PRD_WITH_PRICE  \
# L3_FSF_ID
# ...
